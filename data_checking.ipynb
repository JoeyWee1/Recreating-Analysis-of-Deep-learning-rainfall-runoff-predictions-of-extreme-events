# %% [markdown]
# # Data Checking
# - Just a little bit to play around with the NetCDF files.

# %%
import xarray as xr
ds = xr.open_dataset("Caravan-nc/timeseries/netcdf/camels/camels_01013500.nc")
print(ds.data_vars)
# Out:
# Data variables:
#     dewpoint_temperature_2m_max                    (date) float32 107kB ...
#     dewpoint_temperature_2m_mean                   (date) float32 107kB ...
#     dewpoint_temperature_2m_min                    (date) float32 107kB ...
#     potential_evaporation_sum_ERA5_LAND            (date) float32 107kB ...
#     potential_evaporation_sum_FAO_PENMAN_MONTEITH  (date) float32 107kB ...
#     snow_depth_water_equivalent_max                (date) float32 107kB ...
#     snow_depth_water_equivalent_mean               (date) float32 107kB ...
#     snow_depth_water_equivalent_min                (date) float32 107kB ...
#     streamflow                                     (date) float32 107kB ...
#     surface_net_solar_radiation_max                (date) float32 107kB ...
#     surface_net_solar_radiation_mean               (date) float32 107kB ...
#     surface_net_solar_radiation_min                (date) float32 107kB ...
#     surface_net_thermal_radiation_max              (date) float32 107kB ...
#     surface_net_thermal_radiation_mean             (date) float32 107kB ...
#     surface_net_thermal_radiation_min              (date) float32 107kB ...
#     surface_pressure_max                           (date) float32 107kB ...
#     surface_pressure_mean                          (date) float32 107kB ...
#     surface_pressure_min                           (date) float32 107kB ...
#     temperature_2m_max                             (date) float32 107kB ...
#     temperature_2m_mean                            (date) float32 107kB ...
#     temperature_2m_min                             (date) float32 107kB ...
#     total_precipitation_sum                        (date) float32 107kB ...
#     u_component_of_wind_10m_max                    (date) float32 107kB ...
#     u_component_of_wind_10m_mean                   (date) float32 107kB ...
#     u_component_of_wind_10m_min                    (date) float32 107kB ...
#     v_component_of_wind_10m_max                    (date) float32 107kB ...
#     v_component_of_wind_10m_mean                   (date) float32 107kB ...
#     v_component_of_wind_10m_min                    (date) float32 107kB ...
#     volumetric_soil_water_layer_1_max              (date) float32 107kB ...
#     volumetric_soil_water_layer_1_mean             (date) float32 107kB ...
#     volumetric_soil_water_layer_1_min              (date) float32 107kB ...
#     volumetric_soil_water_layer_2_max              (date) float32 107kB ...
#     volumetric_soil_water_layer_2_mean             (date) float32 107kB ...
#     volumetric_soil_water_layer_2_min              (date) float32 107kB ...
#     volumetric_soil_water_layer_3_max              (date) float32 107kB ...
#     volumetric_soil_water_layer_3_mean             (date) float32 107kB ...
#     volumetric_soil_water_layer_3_min              (date) float32 107kB ...
#     volumetric_soil_water_layer_4_max              (date) float32 107kB ...
#     volumetric_soil_water_layer_4_mean             (date) float32 107kB ...
#     volumetric_soil_water_layer_4_min              (date) float32 107kB ...

# %%
# Adding the water year as a coordinate
def water_year(t):
    '''
    Water year is defined as Oct 1 to Sep 30.
    Oct, Nov, Dec are labelled as regular year + 1
    '''
    return t.dt.year + (t.dt.month >= 10)

ds = ds.assign_coords(water_year=water_year(ds["date"]))
# Out:
# <xarray.DataArray 'water_year' (date: 26662)> Size: 213kB
# array([1951, 1951, 1951, ..., 2024, 2024, 2024], shape=(26662,))
# Coordinates:
#   * date        (date) datetime64[ns] 213kB 1951-01-01 1951-01-02 ... 2023-12-30
#     water_year  (date) int64 213kB 1951 1951 1951 1951 ... 2024 2024 2024 2024
